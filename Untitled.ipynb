# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('relatorio_vendas_robusto.xlsx')

df.head()
# Out:
#   Data da Venda Horário da Venda  Produto        SKU  Categoria  \
# 0    2024-05-14         19:08:38     Saia  SKU-92683   Feminino
# 1    2024-02-08         22:02:04    Tênis  SKU-92963   Infantil
# 2    2024-07-11         20:51:14    Blusa  SKU-24476  Masculino
# 3    2024-01-01         11:49:12  Vestido  SKU-12187  Masculino
# 4    2024-06-14         09:44:55  Jaqueta  SKU-90910    Unissex
#
#   Método de Pagamento        Região      Cliente Origem do Cliente  \
# 0                 Pix         Norte  Cliente_123        Recorrente
# 1                 Pix  Centro-Oeste  Cliente_152              Novo
# 2            Dinheiro         Norte  Cliente_195              Novo
# 3            Dinheiro       Sudeste   Cliente_66              Novo
# 4            Dinheiro  Centro-Oeste  Cliente_127        Recorrente
#
#   Status do Pedido  ... Quantidade  Preço Unitário  Desconto Aplicado (%)  \
# 0        Concluído  ...          4          163.99                    9.0
# ...

# %%
print(df.columns)
# Out:
# Index(['Data da Venda', 'Horário da Venda', 'Produto', 'SKU', 'Categoria',
#        'Método de Pagamento', 'Região', 'Cliente', 'Origem do Cliente',
#        'Status do Pedido', 'Canal de Venda', 'Quantidade', 'Preço Unitário',
#        'Desconto Aplicado (%)', 'Custo Unitário', 'Total da Venda',
#        'Lucro Bruto', 'Frete', 'Prazo de Entrega Estimado (dias)',
#        'Prazo de Entrega Real (dias)', 'Feedback do Cliente'],
#       dtype='object')

# %%
for linha, coluna in df.iterrows():
    display(coluna)
    print('-'*60)
# Out:
# Data da Venda                               2024-05-14
# Horário da Venda                              19:08:38
# Produto                                           Saia
# SKU                                          SKU-92683
# Categoria                                     Feminino
# Método de Pagamento                                Pix
# Região                                           Norte
# Cliente                                    Cliente_123
# Origem do Cliente                           Recorrente
# Status do Pedido                             Concluído
# Canal de Venda                             Loja Física
# Quantidade                                           4
# Preço Unitário                                  163.99
# Desconto Aplicado (%)                              9.0
# Custo Unitário                                  124.37
# Total da Venda                                  596.92
# Lucro Bruto                                     144.22
# ...

# %%
fig = plt.figure()

ax = fig.add_subplot()

data = np.random.standard_normal(5_000).cumsum()

plt.figure(figsize=(10,10))

ax.plot(data, color="black")
